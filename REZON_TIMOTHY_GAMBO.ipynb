# %% [markdown]
# ### __TIMOTHY REZON GAMBO__
# ---

# %% [markdown]
# ### **11133197**
# ---

# %% [markdown]
# ### __BIOMEDICAL ENGINEERING__
# ---

# %% [markdown]
#   ###     **SENG_207_XMAS_PROJECT /[DATA ANALYTICS]**
#   ---

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
Original_dataset=pd.read_csv('red_wine.csv')

# %%
Original_dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4      5.0
# 1         9.8      5.0
# 2         9.8      5.0
# 3         9.8      6.0
# 4         9.4      5.0
# ...       ...      ...
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0
#
# [1599 rows x 12 columns]

# %%
Original_dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# 3      9.8      6.0
# 4      9.4      5.0
# 5      9.4      5.0
# 6      9.4      5.0
# 7     10.0      7.0
# 8      9.5      7.0
# 9     10.5      5.0

# %%
Original_dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1579                 24.0                  32.0  0.99402  3.54       0.60
# 1580                  9.0                  26.0  0.99470  3.36       0.60
# 1581                 24.0                  32.0  0.99402  3.54       0.60
# 1582                 13.0                  27.0  0.99362  3.57       0.50
# 1583                 32.0                  98.0  0.99578  3.33       0.62
# 1584                 24.0                  34.0  0.99484  3.29       0.80
# 1585                 22.0                  48.0  0.99494  3.30       0.84
# 1586                 34.0                  60.0  0.99492  3.34       0.85
# 1587                 18.0                  28.0  0.99483  3.55       0.66
# 1588                 34.0                 102.0  0.99414  3.27       0.78
# 1589                 29.0                  79.0  0.99770  3.29       0.54
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1579     11.3      5.0
# 1580     11.9      6.0
# 1581     11.3      5.0
# 1582     11.9      5.0
# 1583      9.8      5.0
# 1584     11.6      7.0
# 1585     11.5      6.0
# 1586     11.4      6.0
# 1587     10.9      6.0
# 1588     12.8      6.0
# 1589      9.2      5.0
# 1590     11.6      6.0
# 1591     11.6      6.0
# 1592     11.0      6.0
# 1593      9.5      6.0
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0

# %%
Original_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
description=Original_dataset.describe()

# %%
description
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997830
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1598.000000
# mean      3.311113     0.658149    10.422983     5.635795
# std       0.154386     0.169507     1.065668     0.807771
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
Original_dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4      5.0
# 1         9.8      5.0
# 2         9.8      5.0
# 3         9.8      6.0
# 4         9.4      5.0
# ...       ...      ...
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0
#
# [1599 rows x 12 columns]

# %%
complete_data=Original_dataset.dropna()

# %%
complete_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4      5.0
# 1         9.8      5.0
# 2         9.8      5.0
# 3         9.8      6.0
# 4         9.4      5.0
# ...       ...      ...
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0
#
# [1590 rows x 12 columns]

# %% [markdown]
# ### _REPLACING NULL VALUES WITH MEAN_
# ---

# %%
Original_dataset=pd.read_csv('red_wine.csv')

# %%
Original_dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4      5.0
# 1         9.8      5.0
# 2         9.8      5.0
# 3         9.8      6.0
# 4         9.4      5.0
# ...       ...      ...
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0
#
# [1599 rows x 12 columns]

# %%
A=Original_dataset['fixed acidity']. mean()

# %%
B=Original_dataset['volatile acidity']. mean()

# %%
C=Original_dataset['chlorides']. mean()

# %%
D=Original_dataset['free sulfur dioxide'].mean()

# %%
E=Original_dataset['density']. mean()

# %%
F=Original_dataset['quality']. mean()

# %%
Original_dataset['fixed acidity']=Original_dataset['fixed acidity'].fillna(A)

# %%
Original_dataset['volatile acidity']=Original_dataset['volatile acidity'].fillna(B)

# %%
Original_dataset['chlorides']=Original_dataset['chlorides'].fillna(C)

# %%
Original_dataset['free sulfur dioxide']=Original_dataset['free sulfur dioxide'].fillna(D)

# %%
Original_dataset['density']=Original_dataset['density'].fillna(E)

# %%
Original_dataset['quality']=Original_dataset['quality'].fillna(F)

# %%
Original_dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4      5.0
# 1         9.8      5.0
# 2         9.8      5.0
# 3         9.8      6.0
# 4         9.4      5.0
# ...       ...      ...
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0
#
# [1599 rows x 12 columns]

# %%
Original_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
Original_dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
Original_dataset=Original_dataset.drop_duplicates()

# %%
Original_dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4      5.0
# 1         9.8      5.0
# 2         9.8      5.0
# 3         9.8      6.0
# 5         9.4      5.0
# ...       ...      ...
# 1593      9.5      6.0
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0
#
# [1360 rows x 12 columns]

# %% [markdown]
# ###  **CORRELATION BETWEEN MODIFIED DATASET VALUES**

# %% [markdown]
# ---

# %%
Original_dataset.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.253679     0.666754
# volatile acidity          -0.253679          1.000000    -0.550037
# citric acid                0.666754         -0.550037     1.000000
# residual sugar             0.110855         -0.002313     0.143677
# chlorides                  0.085835          0.054840     0.209866
# free sulfur dioxide       -0.139707         -0.020591    -0.047983
# total sulfur dioxide      -0.102660          0.072334     0.047944
# density                    0.669677          0.024102     0.359296
# pH                        -0.685521          0.247132    -0.548681
# sulphates                  0.190178         -0.256904     0.325422
# alcohol                   -0.061216         -0.197714     0.104459
# quality                    0.119190         -0.395077     0.226920
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.110855   0.085835            -0.139707
# volatile acidity           -0.002313   0.054840            -0.020591
# citric acid                 0.143677   0.209866            -0.047983
# residual sugar              1.000000   0.026633             0.160526
# chlorides                   0.026633   1.000000             0.000566
# free sulfur dioxide         0.160526   0.000566             1.000000
# total sulfur dioxide        0.200910   0.045646             0.667116
# density                     0.323452   0.192190            -0.020587
# pH                         -0.083246  -0.271016             0.056598
# sulphates                  -0.011772   0.394582             0.054122
# alcohol                     0.063352  -0.223862            -0.080110
# quality                     0.013905  -0.130830            -0.050863
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.102660  0.669677 -0.685521   0.190178
# volatile acidity                  0.072334  0.024102  0.247132  -0.256904
# citric acid                       0.047944  0.359296 -0.548681   0.325422
# residual sugar                    0.200910  0.323452 -0.083246  -0.011772
# chlorides                         0.045646  0.192190 -0.271016   0.394582
# free sulfur dioxide               0.667116 -0.020587  0.056598   0.054122
# total sulfur dioxide              1.000000  0.076789 -0.078545   0.035004
# density                           0.076789  1.000000 -0.353070   0.144380
# pH                               -0.078545 -0.353070  1.000000  -0.214463
# sulphates                         0.035004  0.144380 -0.214463   1.000000
# alcohol                          -0.218111 -0.504589  0.212653   0.091855
# quality                          -0.178328 -0.184477 -0.056058   0.249312
#
#                        alcohol   quality
# fixed acidity        -0.061216  0.119190
# volatile acidity     -0.197714 -0.395077
# citric acid           0.104459  0.226920
# residual sugar        0.063352  0.013905
# chlorides            -0.223862 -0.130830
# free sulfur dioxide  -0.080110 -0.050863
# total sulfur dioxide -0.218111 -0.178328
# density              -0.504589 -0.184477
# pH                    0.212653 -0.056058
# sulphates             0.091855  0.249312
# alcohol               1.000000  0.480885
# quality               0.480885  1.000000

# %% [markdown]
# ### **_GRAPHICAL REPRESENTATION OF NUMERICAL DATA(ORIGINAL__DATASET)_**

# %% [markdown]
# ---

# %%
graph=Original_dataset[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']]

# %%
plt.plot(graph)
# Out:
# [<matplotlib.lines.Line2D at 0x1c424999d10>,
#  <matplotlib.lines.Line2D at 0x1c4249f89d0>,
#  <matplotlib.lines.Line2D at 0x1c4249f8d10>,
#  <matplotlib.lines.Line2D at 0x1c4249f9290>,
#  <matplotlib.lines.Line2D at 0x1c4249d9650>,
#  <matplotlib.lines.Line2D at 0x1c4249f9990>,
#  <matplotlib.lines.Line2D at 0x1c4249acf50>,
#  <matplotlib.lines.Line2D at 0x1c4248c2190>,
#  <matplotlib.lines.Line2D at 0x1c4249da4d0>,
#  <matplotlib.lines.Line2D at 0x1c4249da850>,
#  <matplotlib.lines.Line2D at 0x1c424922550>,
#  <matplotlib.lines.Line2D at 0x1c424962810>]

# %%
# Generate some random data for demonstration
Original_dataset = np.random.randn(1000)

# Create a histogram
plt.hist(Original_dataset, bins=30, edgecolor='cyan')

# Add labels and title
plt.xlabel('column ')
plt.ylabel('Frequency')
plt.title(' Histogram ')

# Show the plot
plt.show()

# %%
Original_dataset = np.random.randn(100)
y_data = 2 * Original_dataset + np.random.randn(100)

# Create a scatter plot
plt.scatter(Original_dataset, y_data, color='green', marker='o', label='Scatter Plot')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot Diagram')

# Add legend
plt.legend()

# %%
for column in df.columns:
    mplt.figure()
    df[column].plot(kind='hist',title=column) 
mplt.show()

# %% [markdown]
# ###    __Data Analysis Report__

# %% [markdown]
# ---

# %% [markdown]
# ###    **_Fixed Acidity_**
# ### The histogram of the fixed acidity shows a distribution that is slightly right-skewed. This indicates that the majority of wines in our dataset have a fixed acidity around 7% . However, there are a few wines with a higher fixed acidity, which contributes to the right skew of the distribution.

# %% [markdown]
# ###  **_Volatile acidity_**
# ### The histogram of the volatile acidity shows a distribution that is slightly right-skewed. This indicates that the majority of wines in our dataset have a volatile acidity around 0.6-0.7. However, there are a few wines with a higher volatile acidity, which contributes to the slightly right skew of the distribution.

# %% [markdown]
# ### **_Citric acid_**
# ###  The histogram of the citric acid shows a right-skewed distribution. This indicates that majority of wines in our dataset have a citric acid content of 0%. This indicates that most wines have a relatively low citric acid content

# %% [markdown]
# ### **_Residual Sugar_**
# ###  The histogram of the residual sugar shows a right-skewed distribution. This indicates that majority of wines in our dataset have a residual sugar of around 1-2.This indicates that most wines have a relatively low redidual sugar content

# %% [markdown]
# ### **_Chlorides_**
# ### The chlorides histogram shows a nearly right-skewed distribution. This indicates that majority of wines in out dataset have a chloride content of 0.1. This indicates that most wines have a relatively low chloride content.

# %% [markdown]
# ### **_Free Sulfur dioxide_**
# ###  The histogram of the free sulfur dioxide shows a right-skewed distribution. This indicates that majority of wines in out dataset have a free sulfur-dioxide content of 0-10.A clear indication relatively low free sulfur dioxide content

# %% [markdown]
# ###  **_Total sulfur dioxide_**
# ### The histogram of the total sulfur dioxide shows a right-skewed distribution. This indicates that majority of wines in out dataset have a total sulfur dioxide content of 25. This indicates that most wines have a relatively low total sulfur dioxide content

# %% [markdown]
# ### **_Density_**
# ###   The density histogram shows a nearly normal distribution with a slight right-skew. This indicates that the majority of wine in our dataset have a density of 0.996.

# %% [markdown]
# ### **_pH_**
# ### The pH histogram presents a nearly normal distribution. This suggests that most wines have a pH around 3.3. This is within the expected range, as wine is typically slightly acidic.

# %% [markdown]
# ###  **_Sulphates_**
# ### The sulphates histogram is right-skewed. This indicates that most wines have a relatively low sulphate content. However, there are a few exceptions with higher sulphate content, which are represented by the long tail on the right side of the distribution.

# %% [markdown]
# ### **Alcohol Content_**
# ### The histogram of the alcohol content shows a distribution that is slightly right-skewed. This indicates that the majority of wines in our dataset have an alcohol content around 9%-10%. However, there are a few wines with a higher alcohol content, which contributes to the right skew of the distribution.

# %% [markdown]
#  ### **_Quality_**
# ### The histogram for wine quality shows a nearly normal ditribution with a slight left-skew.This however shows that majority of wines in our dataset have a quality of 5 with a few with a higher quality of 6 with contribute to the slightly left-skew.
